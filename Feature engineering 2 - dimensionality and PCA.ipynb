# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sqlalchemy import create_engine
import scipy.stats as stats
# %matplotlib inline

# %%
postgres_user = 'dsbc_student'
postgres_pw = '7*.8G9QH21'
postgres_host = '142.93.121.174'
postgres_port = '5432'
postgres_db = 'useducation'

engine = create_engine('postgresql://{}:{}@{}:{}/{}'.format(
    postgres_user, postgres_pw, postgres_host, postgres_port, postgres_db))

df = pd.read_sql_query('select * from useducation',con=engine)

# no need for an open connection, 
# as we're only doing a single query
engine.dispose()

# %%
df.head()
# Out:
#        PRIMARY_KEY       STATE  YEAR  ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# 0     1992_ALABAMA     ALABAMA  1992     NaN      2678885.0         304177.0
# 1      1992_ALASKA      ALASKA  1992     NaN      1049591.0         106780.0
# 2     1992_ARIZONA     ARIZONA  1992     NaN      3258079.0         297888.0
# 3    1992_ARKANSAS    ARKANSAS  1992     NaN      1711959.0         178571.0
# 4  1992_CALIFORNIA  CALIFORNIA  1992     NaN     26260025.0        2072470.0
#
#    STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  INSTRUCTION_EXPENDITURE  \
# 0      1659028.0       715680.0          2653798.0                1481703.0
# 1       720711.0       222100.0           972488.0                 498362.0
# 2      1369815.0      1590376.0          3401580.0                1435908.0
# 3       958785.0       574603.0          1743022.0                 964323.0
# 4     16546514.0      7641041.0         27138832.0               14358922.0
#
# ...

# %%
cols_to_fill = df.columns[:-4]
states = df['STATE'].unique()

for state in states:
    df.loc[df['STATE'] == state, cols_to_fill] = df.loc[df['STATE'] == state, cols_to_fill].interpolate()
    
df.dropna(inplace=True)
df.describe()
# Out:
#               YEAR        ENROLL  TOTAL_REVENUE  FEDERAL_REVENUE  \
# count   466.000000  4.660000e+02   4.660000e+02     4.660000e+02
# mean   2008.577253  9.442125e+05   1.078853e+07     9.568659e+05
# std       5.779779  1.122051e+06   1.356335e+07     1.330702e+06
# min    1996.000000  4.417900e+04   6.788740e+05     5.787000e+04
# 25%    2005.000000  2.794832e+05   2.712660e+06     2.614470e+05
# 50%    2009.000000  6.639415e+05   6.106834e+06     5.544340e+05
# 75%    2013.000000  1.018588e+06   1.222407e+07     1.033414e+06
# max    2017.000000  6.307022e+06   8.921726e+07     9.990221e+06
#
#        STATE_REVENUE  LOCAL_REVENUE  TOTAL_EXPENDITURE  \
# count   4.660000e+02   4.660000e+02       4.660000e+02
# mean    4.999548e+06   4.832112e+06       1.086947e+07
# std     6.405481e+06   6.325995e+06       1.373667e+07
# min     0.000000e+00   2.853100e+04       7.032450e+05
# 25%     1.491747e+06   9.513430e+05       2.670300e+06
# ...

# %% [markdown]
# # 1. Create a new score variable from the weighted averages of the all score variables in the datasets. Notice that the number of students in the fourth grade isn't the same with the number of students in the eighth grade. So, you should weight the scores appropriately!.

# %%
avg_scores_grade4 = (df['AVG_MATH_4_SCORE']+ df['AVG_READING_4_SCORE'])/2
avg_scores_grade8 = (df['AVG_MATH_8_SCORE']+ df['AVG_READING_8_SCORE'])/2
weighted_scores_grade4 = avg_scores_grade4*(df['GRADES_4_G']/(df['GRADES_4_G']+df['GRADES_8_G']))
weighted_scores_grade8 = avg_scores_grade8*(df['GRADES_8_G']/(df['GRADES_4_G']+df['GRADES_8_G']))
df['overall_score'] = weighted_scores_grade4 + weighted_scores_grade8
df['overall_score']
# Out:
# 209     235.106342
# 211     238.321404
# 212     240.773675
# 213     234.719834
# 214     247.750273
#            ...
# 1487    259.594501
# 1488    255.009879
# 1489    249.950079
# 1490    251.726455
# 1491    257.259108
# Name: overall_score, Length: 466, dtype: float64

# %% [markdown]
# # 2. What are the correlations between this newly created score variable and the expenditure types? Which one of the expenditure type is more correlated than the others?

# %%
df[['overall_score', 'TOTAL_EXPENDITURE', 'INSTRUCTION_EXPENDITURE', 'SUPPORT_SERVICES_EXPENDITURE', 'OTHER_EXPENDITURE', 'CAPITAL_OUTLAY_EXPENDITURE']].corr()
# Out:
#                               overall_score  TOTAL_EXPENDITURE  \
# overall_score                      1.000000           0.074155
# TOTAL_EXPENDITURE                  0.074155           1.000000
# INSTRUCTION_EXPENDITURE            0.087386           0.990255
# SUPPORT_SERVICES_EXPENDITURE       0.079002           0.992988
# OTHER_EXPENDITURE                  0.010959           0.943702
# CAPITAL_OUTLAY_EXPENDITURE        -0.005389           0.925784
#
#                               INSTRUCTION_EXPENDITURE  \
# overall_score                                0.087386
# TOTAL_EXPENDITURE                            0.990255
# INSTRUCTION_EXPENDITURE                      1.000000
# SUPPORT_SERVICES_EXPENDITURE                 0.974399
# OTHER_EXPENDITURE                            0.902173
# CAPITAL_OUTLAY_EXPENDITURE                   0.884798
#
#                               SUPPORT_SERVICES_EXPENDITURE  OTHER_EXPENDITURE  \
# ...

# %% [markdown]
# INSTRUCTION_EXPENDITURE	is the variable that is most correlated with overall_score.

# %% [markdown]
# # 3. Now, apply PCA to the four expenditure types. How much of the total variance is explained by the first component?

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

X = df[['INSTRUCTION_EXPENDITURE', 'SUPPORT_SERVICES_EXPENDITURE', 'OTHER_EXPENDITURE', 'CAPITAL_OUTLAY_EXPENDITURE']]
X = StandardScaler().fit_transform(X)

pca = PCA(n_components=1)
df['pca_1'] = pca.fit_transform(X)
pca.explained_variance_ratio_
# Out:
# array([0.9430175])

# %% [markdown]
# 94% of the variance is explained by the first principal component.

# %% [markdown]
# # 4. What is the correlation between the overall score variable and the first principal component?

# %%
df[['overall_score', 'pca_1']].corr()
# Out:
#                overall_score     pca_1
# overall_score       1.000000  0.044596
# pca_1               0.044596  1.000000

# %% [markdown]
# The correlation coefficient between overall_score and the first principal component is .044596. This is less than INSTRUCTION_EXPENDITURE and SUPPPORT_SERVICES_EXPENDITURE.

# %% [markdown]
# # 5. If you were to choose the best variables for your model, would you prefer using the 1st principal component instead of the expenditure variables? Why?

# %% [markdown]
# The expenditure variables are more correlated with the overall score than the first principal component. Therefore, it would be better to use INSTRUCTION_EXPENDITURE.
