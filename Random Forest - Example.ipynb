# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Replace the path with the correct path for your data.
df = pd.read_csv(
    'https://www.dropbox.com/s/0so14yudedjmm5m/LoanStats3d.csv?dl=1',
    skipinitialspace=True,
    header=1
)

# Note the warning about dtypes.
# Out:
# //anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (0,19,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#          id   member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68009401  72868139.0    16000.0      16000.0          16000.0   60 months
# 1  68354783  73244544.0     9600.0       9600.0           9600.0   36 months
# 2  68466916  73356753.0    25000.0      25000.0          25000.0   36 months
# 3  68466961  73356799.0    28000.0      28000.0          28000.0   36 months
# 4  68495092  73384866.0     8650.0       8650.0           8650.0   36 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   14.85%       379.39     C        C5  ...                0.0
# 1    7.49%       298.58     A        A4  ...                0.0
# 2    7.49%       777.55     A        A4  ...                0.0
# 3    6.49%       858.05     A        A2  ...                0.0
# 4   19.89%       320.99     E        E3  ...                0.0
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# 0                2.0           78.9               0.0                  0.0
# 1                2.0          100.0              66.7                  0.0
# 2                0.0          100.0              20.0                  0.0
# 3                0.0           91.7              22.2                  0.0
# 4               12.0          100.0              50.0                  1.0
#
#   tax_liens tot_hi_cred_lim total_bal_ex_mort total_bc_limit  \
# 0       2.0        298100.0           31329.0       281300.0
# 1       0.0         88635.0           55387.0        12500.0
# 2       0.0        373572.0           68056.0        38400.0
# 3       0.0        304003.0           74920.0        41500.0
# 4       0.0         38998.0           18926.0         2750.0
#
#   total_il_high_credit_limit
# 0                    13400.0
# 1                    75635.0
# 2                    82117.0
# 3                    42503.0
# 4                    18248.0
#
# [5 rows x 111 columns]

# %%
categorical_var = df.describe(include='O').columns
categorical_var = df[categorical_var]
categorical_var.nunique()
# Out:
# id                           421097
# term                              2
# int_rate                        110
# grade                             7
# sub_grade                        35
#                               ...
# last_pymnt_d                     25
# next_pymnt_d                      4
# last_credit_pull_d               26
# application_type                  2
# verification_status_joint         3
# Length: 26, dtype: int64

# %%
# converting id and interest rate to numeric
df['id'] = pd.to_numeric(df['id'], errors='coerce')
df['int_rate'] = pd.to_numeric(df['int_rate'].str.strip('%'))

# %%
# dropping categorical rows that have too many or too few unique values
for col in categorical_var.columns:
    if df[col].nunique() > 30 or df[col].nunique() == 1:
        df.drop(col, 1, inplace=True)

# %%
# dropping the last two rows that don't contain data

df = df[:-2]

# %%
from scipy.stats import chi2_contingency

# A function to find cramers value for two categorical variables
def cramers_v(x,y):
    confusion_matrix = pd.crosstab(x,y)
    chi2 = chi2_contingency(confusion_matrix)[0]
    n = confusion_matrix.sum().sum()
    r,k = confusion_matrix.shape
    return (chi2/(n*min((k-1),(r-1))))**.5

# %%
# Let's find the categorical variables most associated with loan status
categorical_cols = df.describe(include='O').columns
categorical_var = df[categorical_cols]

cramerv_values = {}

for col in categorical_var.columns:
    x = df[col]
    y = df['loan_status']
    cramerv_values[col] = cramers_v(x, y)
cramerv_values = sorted(cramerv_values.items(), key = lambda x: x[1])
cramerv_values
# Out:
# [('application_type', 0.007726412574411751),
#  ('emp_length', 0.011614449191061946),
#  ('purpose', 0.03160615087089259),
#  ('title', 0.031940728119615465),
#  ('home_ownership', 0.03642382729851921),
#  ('next_pymnt_d', 0.03843496997279434),
#  ('verification_status', 0.054478979202925194),
#  ('issue_d', 0.0669618207904894),
#  ('initial_list_status', 0.0766660904150539),
#  ('grade', 0.09059541903269518),
#  ('term', 0.09200651502010207),
#  ('verification_status_joint', 0.11001013034043629),
#  ('last_credit_pull_d', 0.3138093468675081),
#  ('last_pymnt_d', 0.46443163453241276),
#  ('loan_status', 1.0)]

# %% [markdown]
# The categorical feature most associated with loan_status is 'last_pymnt_d'.
# ##### I will add this feature to our model

# %%
categorical_features = pd.get_dummies(df[['last_pymnt_d']], drop_first=True)

# %% [markdown]
# ##### Now let's look at the continuous variables

# %%
# First let's look at the correlation of all the continuous variables with our target variable
continous_cols = df.describe().columns
continuous_var = df[continous_cols]

# I converted the target to dummy variables to show the correlation
pd.options.display.max_rows = 100
print(pd.concat([continuous_var, pd.get_dummies(df['loan_status'])], axis=1).corr().iloc[:, -6:])
pd.options.display.max_rows = 10
# Out:
#                                  Current   Default  Fully Paid  \
# member_id                       0.146156  0.004429   -0.119457
# loan_amnt                       0.015382  0.001988   -0.033211
# funded_amnt                     0.015382  0.001988   -0.033211
# funded_amnt_inv                 0.015401  0.001965   -0.033178
# installment                    -0.014418  0.002959   -0.007999
# annual_inc                      0.003351 -0.001643    0.017387
# dti                             0.004559  0.003209   -0.028381
# delinq_2yrs                     0.000854  0.000028   -0.013399
# inq_last_6mths                 -0.083236  0.009081    0.034420
# mths_since_last_delinq         -0.018144 -0.000026    0.028909
# mths_since_last_record         -0.044888  0.002225    0.031625
# open_acc                       -0.004811  0.003726   -0.006400
# pub_rec                        -0.013627  0.003274    0.004848
# revol_bal                       0.035122 -0.004585   -0.021251
# total_acc                      -0.050490  0.001583    0.053061
# out_prncp                       0.555151  0.028535   -0.519681
# out_prncp_inv                   0.555196  0.028514   -0.519706
# total_pymnt                    -0.320038 -0.020238    0.503723
# total_pymnt_inv                -0.320022 -0.020246    0.503716
# total_rec_prncp                -0.389478 -0.023008    0.611635
# total_rec_int                   0.180020  0.004247   -0.195000
# total_rec_late_fee             -0.073964  0.009002   -0.029847
# recoveries                     -0.185216 -0.005497   -0.064921
# collection_recovery_fee        -0.185970 -0.005520   -0.065185
# last_pymnt_amnt                -0.569426 -0.015336    0.753773
# collections_12_mths_ex_med      0.001837 -0.001080   -0.010047
# mths_since_last_major_derog    -0.019705 -0.000463    0.021722
# policy_code                          NaN       NaN         NaN
# annual_inc_joint                0.038181 -0.052929    0.012936
# dti_joint                       0.008575  0.067172   -0.034827
# acc_now_delinq                 -0.001495 -0.002431   -0.001725
# tot_coll_amt                   -0.000171 -0.000348    0.001692
# tot_cur_bal                    -0.002189 -0.008145    0.039465
# open_acc_6m                    -0.100557  0.018583    0.065110
# open_il_6m                      0.000309  0.015517   -0.010766
# open_il_12m                    -0.102651  0.023282    0.063359
# open_il_24m                    -0.101602  0.021273    0.062345
# mths_since_rcnt_il              0.065347 -0.018514   -0.041563
# total_bal_il                   -0.006142  0.003743   -0.000804
# il_util                        -0.063716  0.004015    0.041305
# open_rv_12m                    -0.070558  0.018592    0.043258
# open_rv_24m                    -0.077680  0.015212    0.045515
# max_bal_bc                      0.023974 -0.009425   -0.007788
# all_util                        0.001610  0.005560   -0.046485
# total_rev_hi_lim                0.025934 -0.006605    0.006790
# inq_fi                         -0.062974  0.010266    0.030038
# total_cu_tl                    -0.047163  0.003887    0.057367
# inq_last_12m                   -0.097836  0.019410    0.060340
# acc_open_past_24mths           -0.132478  0.014486    0.071736
# avg_cur_bal                    -0.004915 -0.009216    0.045476
# bc_open_to_buy                  0.005364 -0.007332    0.044218
# bc_util                         0.048001  0.004374   -0.087121
# chargeoff_within_12_mths       -0.001787 -0.000605    0.000455
# delinq_amnt                    -0.001052 -0.000763    0.000707
# mo_sin_old_il_acct              0.031891 -0.003234   -0.013532
# mo_sin_old_rev_tl_op            0.052325 -0.004901   -0.016640
# mo_sin_rcnt_rev_tl_op           0.067427 -0.008024   -0.038524
# mo_sin_rcnt_tl                  0.081576 -0.009564   -0.048684
# mort_acc                       -0.016541 -0.007155    0.057780
# mths_since_recent_bc            0.062433 -0.007065   -0.035530
# mths_since_recent_bc_dlq       -0.030643 -0.004263    0.037132
# mths_since_recent_inq           0.072840 -0.005743   -0.038639
# mths_since_recent_revol_delinq -0.026291 -0.001734    0.034548
# num_accts_ever_120_pd          -0.015712  0.001660    0.009826
# num_actv_bc_tl                  0.042046  0.001452   -0.052339
# num_actv_rev_tl                 0.031898  0.004351   -0.057560
# num_bc_sats                     0.010027  0.000347   -0.006677
# num_bc_tl                      -0.027150  0.000848    0.038957
# num_il_tl                      -0.039417  0.002498    0.026457
# num_op_rev_tl                  -0.002923  0.002465   -0.006038
# num_rev_accts                  -0.033974  0.001594    0.039406
# num_rev_tl_bal_gt_0             0.035653  0.004359   -0.061738
# num_sats                       -0.004537  0.003719   -0.006783
# num_tl_120dpd_2m               -0.002649 -0.001091    0.000609
# num_tl_30dpd                   -0.000952 -0.001784   -0.000055
# num_tl_90g_dpd_24m             -0.003996 -0.000949   -0.001855
# num_tl_op_past_12m             -0.126972  0.012649    0.071918
# pct_tl_nvr_dlq                 -0.010820 -0.005022    0.015095
# percent_bc_gt_75                0.027917  0.005730   -0.070830
# pub_rec_bankruptcies           -0.040475  0.005380    0.032111
# tax_liens                       0.013446  0.001183   -0.017280
# tot_hi_cred_lim                 0.003654 -0.009085    0.038666
# total_bal_ex_mort               0.007840  0.000159   -0.007585
# total_bc_limit                  0.038308 -0.007774    0.006591
# total_il_high_credit_limit     -0.000985  0.001225   -0.001477
# Charged Off                    -0.400083 -0.011874   -0.140234
# Current                         1.000000 -0.063811   -0.753602
# Default                        -0.063811  1.000000   -0.022367
# Fully Paid                     -0.753602 -0.022367    1.000000
# In Grace Period                -0.149283 -0.004431   -0.052326
# Late (16-30 days)              -0.098402 -0.002921   -0.034491
# Late (31-120 days)             -0.222884 -0.006615   -0.078124
#
#                                 In Grace Period  Late (16-30 days)  \
# member_id                             -0.000748           0.005096
# loan_amnt                              0.011779           0.009891
# funded_amnt                            0.011779           0.009891
# funded_amnt_inv                        0.011769           0.009872
# installment                            0.015357           0.011804
# annual_inc                            -0.000508          -0.001678
# dti                                    0.005063           0.004066
# delinq_2yrs                            0.012607           0.006480
# inq_last_6mths                         0.011080           0.013712
# mths_since_last_delinq                -0.010979          -0.005267
# mths_since_last_record                -0.002376           0.003025
# open_acc                               0.002355           0.005288
# pub_rec                                0.002760           0.002168
# revol_bal                             -0.002287          -0.002453
# total_acc                              0.001479           0.002731
# out_prncp                              0.052958           0.039482
# out_prncp_inv                          0.052952           0.039467
# total_pymnt                           -0.015422          -0.011901
# total_pymnt_inv                       -0.015425          -0.011910
# total_rec_prncp                       -0.028790          -0.021241
# total_rec_int                          0.044390           0.030497
# total_rec_late_fee                     0.040559           0.038381
# recoveries                            -0.012860          -0.008477
# collection_recovery_fee               -0.012913          -0.008512
# last_pymnt_amnt                       -0.038199          -0.024854
# collections_12_mths_ex_med             0.002628           0.000629
# mths_since_last_major_derog           -0.007774          -0.000306
# policy_code                                 NaN                NaN
# annual_inc_joint                      -0.040761          -0.026562
# dti_joint                             -0.020025           0.019949
# acc_now_delinq                         0.001555          -0.001024
# tot_coll_amt                          -0.000561           0.003098
# tot_cur_bal                           -0.003728          -0.002539
# open_acc_6m                           -0.010288           0.025248
# open_il_6m                            -0.007728           0.014232
# open_il_12m                           -0.010340           0.026185
# open_il_24m                           -0.005719           0.026217
# mths_since_rcnt_il                     0.000484          -0.017830
# total_bal_il                          -0.007203           0.013684
# il_util                               -0.000723           0.008011
# open_rv_12m                           -0.002270           0.016604
# open_rv_24m                            0.003269           0.011637
# max_bal_bc                            -0.013025           0.004412
# all_util                               0.018173           0.027794
# total_rev_hi_lim                      -0.014248          -0.007676
# inq_fi                                -0.004782           0.018510
# total_cu_tl                            0.003646           0.002505
# inq_last_12m                           0.002568           0.014817
# acc_open_past_24mths                   0.015246           0.016068
# avg_cur_bal                           -0.004719          -0.004113
# bc_open_to_buy                        -0.025689          -0.013729
# bc_util                                0.025631           0.012457
# chargeoff_within_12_mths               0.003420          -0.001420
# delinq_amnt                           -0.001243          -0.000860
# mo_sin_old_il_acct                    -0.002510          -0.001258
# mo_sin_old_rev_tl_op                  -0.013419          -0.005320
# mo_sin_rcnt_rev_tl_op                 -0.005632          -0.008022
# mo_sin_rcnt_tl                        -0.008135          -0.007442
# mort_acc                              -0.011905          -0.008515
# mths_since_recent_bc                  -0.005130          -0.004721
# mths_since_recent_bc_dlq              -0.010630          -0.001041
# mths_since_recent_inq                 -0.007899          -0.009780
# mths_since_recent_revol_delinq        -0.009946          -0.004168
# num_accts_ever_120_pd                  0.007853           0.003198
# num_actv_bc_tl                        -0.002362           0.003379
# num_actv_rev_tl                        0.008148           0.007706
# num_bc_sats                           -0.010288          -0.001735
# num_bc_tl                             -0.011589          -0.003950
# num_il_tl                              0.012994           0.007487
# num_op_rev_tl                         -0.004023           0.002635
# num_rev_accts                         -0.006741          -0.000970
# num_rev_tl_bal_gt_0                    0.008881           0.008074
# num_sats                               0.002361           0.005344
# num_tl_120dpd_2m                      -0.001745           0.000788
# num_tl_30dpd                           0.002614          -0.001376
# num_tl_90g_dpd_24m                     0.005930           0.003191
# num_tl_op_past_12m                     0.013507           0.011912
# pct_tl_nvr_dlq                        -0.012517          -0.005245
# percent_bc_gt_75                       0.028747           0.013216
# pub_rec_bankruptcies                   0.000038           0.000786
# tax_liens                              0.002765           0.001290
# tot_hi_cred_lim                       -0.006621          -0.004111
# total_bal_ex_mort                      0.005963           0.004681
# total_bc_limit                        -0.022475          -0.012040
# total_il_high_credit_limit             0.006928           0.005943
# Charged Off                           -0.027779          -0.018311
# Current                               -0.149283          -0.098402
# Default                               -0.004431          -0.002921
# Fully Paid                            -0.052326          -0.034491
# In Grace Period                        1.000000          -0.006832
# Late (16-30 days)                     -0.006832           1.000000
# Late (31-120 days)                    -0.015476          -0.010201
#
#                                 Late (31-120 days)
# member_id                                 0.008412
# loan_amnt                                 0.009339
# funded_amnt                               0.009339
# funded_amnt_inv                           0.009298
# installment                               0.013250
# annual_inc                               -0.010951
# dti                                       0.010120
# delinq_2yrs                               0.012031
# inq_last_6mths                            0.030313
# mths_since_last_delinq                   -0.004338
# mths_since_last_record                    0.006159
# open_acc                                  0.010193
# pub_rec                                   0.006563
# revol_bal                                -0.013080
# total_acc                                 0.002837
# out_prncp                                 0.092312
# out_prncp_inv                             0.092278
# total_pymnt                              -0.052595
# total_pymnt_inv                          -0.052611
# total_rec_prncp                          -0.068905
# total_rec_int                             0.043749
# total_rec_late_fee                        0.088261
# recoveries                               -0.019201
# collection_recovery_fee                  -0.019279
# last_pymnt_amnt                          -0.057809
# collections_12_mths_ex_med                0.005228
# mths_since_last_major_derog               0.001363
# policy_code                                    NaN
# annual_inc_joint                          0.065685
# dti_joint                                -0.048674
# acc_now_delinq                            0.000576
# tot_coll_amt                             -0.000224
# tot_cur_bal                              -0.020978
# open_acc_6m                               0.038118
# open_il_6m                                0.007376
# open_il_12m                               0.033943
# open_il_24m                               0.036447
# mths_since_rcnt_il                       -0.030227
# total_bal_il                              0.022825
# il_util                                   0.034619
# open_rv_12m                               0.028110
# open_rv_24m                               0.037258
# max_bal_bc                               -0.020515
# all_util                                  0.031372
# total_rev_hi_lim                         -0.022262
# inq_fi                                    0.030475
# total_cu_tl                              -0.012283
# inq_last_12m                              0.045886
# acc_open_past_24mths                      0.045804
# avg_cur_bal                              -0.023359
# bc_open_to_buy                           -0.028906
# bc_util                                   0.017356
# chargeoff_within_12_mths                 -0.003155
# delinq_amnt                              -0.000319
# mo_sin_old_il_acct                       -0.008203
# mo_sin_old_rev_tl_op                     -0.024259
# mo_sin_rcnt_rev_tl_op                    -0.021126
# mo_sin_rcnt_tl                           -0.025372
# mort_acc                                 -0.023426
# mths_since_recent_bc                     -0.020621
# mths_since_recent_bc_dlq                 -0.001497
# mths_since_recent_inq                    -0.022629
# mths_since_recent_revol_delinq           -0.002318
# num_accts_ever_120_pd                     0.009123
# num_actv_bc_tl                            0.006488
# num_actv_rev_tl                           0.016591
# num_bc_sats                               0.000533
# num_bc_tl                                -0.005794
# num_il_tl                                 0.011812
# num_op_rev_tl                             0.009238
# num_rev_accts                            -0.000681
# num_rev_tl_bal_gt_0                       0.016717
# num_sats                                  0.010230
# num_tl_120dpd_2m                          0.001210
# num_tl_30dpd                             -0.001279
# num_tl_90g_dpd_24m                        0.005321
# num_tl_op_past_12m                        0.041698
# pct_tl_nvr_dlq                           -0.008680
# percent_bc_gt_75                          0.018788
# pub_rec_bankruptcies                      0.009457
# tax_liens                                -0.000141
# tot_hi_cred_lim                          -0.024316
# total_bal_ex_mort                         0.000122
# total_bc_limit                           -0.029640
# total_il_high_credit_limit                0.003748
# Charged Off                              -0.041475
# Current                                  -0.222884
# Default                                  -0.006615
# Fully Paid                               -0.078124
# In Grace Period                          -0.015476
# Late (16-30 days)                        -0.010201
# Late (31-120 days)                        1.000000

# %%
# The possible features are the features most correlated with our target variable
possible_features = ['collection_recovery_fee', 'recoveries', 'out_prncp_inv', 'total_rec_prncp', 'total_pymnt_inv',
                     'last_pymnt_amnt', 'out_prncp', 'total_pymnt']

# %%
# Let's check the intercorrelation between our possible features

df[possible_features].corr()
# Out:
#                          collection_recovery_fee  recoveries  out_prncp_inv  \
# collection_recovery_fee                 1.000000    0.973343      -0.128250
# recoveries                              0.973343    1.000000      -0.127730
# out_prncp_inv                          -0.128250   -0.127730       1.000000
# total_rec_prncp                        -0.100695   -0.100933      -0.135268
# total_pymnt_inv                        -0.039150   -0.038240       0.048055
# last_pymnt_amnt                        -0.045996   -0.045958      -0.371058
# out_prncp                              -0.128244   -0.127724       0.999997
# total_pymnt                            -0.039152   -0.038244       0.048092
#
#                          total_rec_prncp  total_pymnt_inv  last_pymnt_amnt  \
# collection_recovery_fee        -0.100695        -0.039150        -0.045996
# recoveries                     -0.100933        -0.038240        -0.045958
# out_prncp_inv                  -0.135268         0.048055        -0.371058
# total_rec_prncp                 1.000000         0.964892         0.817310
# total_pymnt_inv                 0.964892         1.000000         0.742462
# last_pymnt_amnt                 0.817310         0.742462         1.000000
# out_prncp                      -0.135324         0.048012        -0.371040
# total_pymnt                     0.964876         0.999997         0.742504
#
#                          out_prncp  total_pymnt
# collection_recovery_fee  -0.128244    -0.039152
# recoveries               -0.127724    -0.038244
# out_prncp_inv             0.999997     0.048092
# total_rec_prncp          -0.135324     0.964876
# total_pymnt_inv           0.048012     0.999997
# last_pymnt_amnt          -0.371040     0.742504
# out_prncp                 1.000000     0.048053
# total_pymnt               0.048053     1.000000

# %%
# Because of the intercorrelation, I will only use two of the possible features as continuous features. 
continuous_features = ['last_pymnt_amnt', 'out_prncp']
continuous_features = df[continuous_features]

# %%
model_features = pd.concat([continuous_features, categorical_features], axis=1)
target = df['loan_status']

from sklearn import ensemble
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split

rfc = ensemble.RandomForestClassifier(n_estimators=5, max_depth=3)
X = model_features
Y = target
X = X.dropna(axis=1)

print(cross_val_score(rfc, X, Y, cv=10))
# Out:
# [0.90643775 0.93935076 0.94395764 0.8920947  0.89679411 0.89145096
#  0.88491771 0.90441473 0.89543306 0.90352919]

# %% [markdown]
# ### Let' see what happens if we drop the categorical features from our model

# %%
model_features = continuous_features
target = df['loan_status']

rfc = ensemble.RandomForestClassifier(n_estimators=5, max_depth=3)
X = model_features
Y = target
X = X.dropna(axis=1)

print(cross_val_score(rfc, X, Y, cv=10))
# Out:
# [0.94433758 0.94547743 0.94533495 0.9441951  0.94673474 0.94668725
#  0.94414496 0.94661474 0.94475978 0.94216976]

# %% [markdown]
# The model improved, and so it seems the categorical features hurt our model.

# %% [markdown]
# ### Let's see if we can achieve above 90% accuracy without any features related to payment amount or outstanding principal.

# %%
# First let's see how our model performs with all the continous variables
model_features = continuous_var
target = df['loan_status'] 

rfc = ensemble.RandomForestClassifier(n_estimators=5, max_depth=5)
X = model_features
Y = target
X = X.dropna(axis=1)

print(cross_val_score(rfc, X, Y, cv=10))
# Out:
# [0.95340885 0.95585476 0.95649593 0.9555698  0.94286393 0.95884588
#  0.95314541 0.95620889 0.95183699 0.94936589]

# %% [markdown]
# At the moment the model performs better than 90%. Let's see if it stays this way after we drop the related features.

# %%
# First let's find out what is related to payment amount and outstanding principal
print('Correlation of out_prncp:')
print('')
print(df.corr()['out_prncp'].sort_values(ascending=False).head(10))
print('-------------------------------')
print('Correlation of last_pymnt_amnt:')
print('')
print(df.corr()['last_pymnt_amnt'].sort_values(ascending=False).head(10))
# Out:
# Correlation of out_prncp:
#
# out_prncp           1.000000
# out_prncp_inv       0.999997
# total_rec_int       0.684606
# loan_amnt           0.623926
# funded_amnt         0.623926
# funded_amnt_inv     0.623858
# installment         0.506732
# max_bal_bc          0.296159
# annual_inc_joint    0.294799
# total_bc_limit      0.231633
# Name: out_prncp, dtype: float64
# -------------------------------
# Correlation of last_pymnt_amnt:
#
# last_pymnt_amnt    1.000000
# total_rec_prncp    0.817310
# total_pymnt        0.742504
# total_pymnt_inv    0.742462
# installment        0.264130
# funded_amnt_inv    0.259878
# loan_amnt          0.259864
# funded_amnt        0.259864
# tot_hi_cred_lim    0.135725
# tot_cur_bal        0.131646
# Name: last_pymnt_amnt, dtype: float64

# %%
# Let's drop all the related features from our model

model_features = continuous_var.drop(['out_prncp', 'out_prncp_inv', 'total_rec_prncp',
                                              'total_pymnt', 'total_pymnt_inv'], axis=1)
target = df['loan_status'] 

rfc = ensemble.RandomForestClassifier(n_estimators=5, max_depth=5)
X = model_features
Y = target
X = X.dropna(axis=1)

print(cross_val_score(rfc, X, Y, cv=10))
# Out:
# [0.82907079 0.87986512 0.89273586 0.77402579 0.88546664 0.86946094
#  0.76385096 0.8720701  0.90372147 0.90526291]

# %% [markdown]
# After dropping all the related features, the model does not perform above 90%. There are no other features to add to the data set to get this number above 90%. Perhaps changing some of parameters of random forest might help. However, I still don't believe it is possible to get this model above 90% with those features removed.
